# %% [markdown]
# ### Loading and Processing Financial Data

# %%
companies_data=[]
for file_name in file_list:
    df = prep.load_clean_data(folder_path, file_name)
    df = prep.map_variable_names(df)
    df = prep.keep_relevant_variables_only(df)
    df = prep.clean_and_cast_to_float(df)
    df = prep.get_financial_KPIs(df)
    companies_data.append(df)
df_financial = pd.concat(companies_data)
df_financial
# Out:
#    TICKER  Year  Current_Ratio  Debt_to_Equity Net_Income_to_Assets  \
# 0       A  2012       2.445325        1.032015              0.10993
# 1       A  2013       3.110487        1.020420             0.069931
# 2       A  2014       3.231492        1.043199             0.043272
# 3       A  2015       3.776639        0.793525             0.052102
# 4       A  2016       3.846561        0.835610             0.058601
# ..    ...   ...            ...             ...                  ...
# 7     XOM  2019       0.782197        0.822663             0.039674
# 8     XOM  2020       0.796498        1.027356            -0.072319
# 9     XOM  2021       1.044330        0.929174             0.065479
# 10    XOM  2022       1.414020        0.822796             0.153927
# 11    XOM  2023       1.479102        0.770587             0.097914
#
#    Operating_Margin  Cash_Ratio  Operating_Cash_Flow_Ratio
# 0          0.163167    0.439357                   0.230530
# ...

# %% [markdown]
# # Loading ESG data

# %%
esg_overall         = pd.read_excel("data/esg/esg_overall.xlsx")
esg_environmental   = pd.read_excel("data/esg/esg_environmental.xlsx")
esg_social          = pd.read_excel("data/esg/esg_social.xlsx")
esg_governance      = pd.read_excel("data/esg/esg_governance.xlsx")
esg_environmental
# Out:
#     TICKER                               Settore  2015  2016  2017  2018  \
# 0        A       Healthcare Equipment & Supplies  1.50  1.50  1.50  1.50
# 1      AAL     Passenger Transportation Services  1.71  1.50  1.60  0.93
# 2     ABNB                Software & IT Services   NaN   NaN   NaN   NaN
# 3     ACGL                             Insurance  0.00  0.00  0.00  0.00
# 4      ADI  Semicouctors & Semicouctor Equipment  3.35  3.38  4.69  4.95
# ..     ...                                   ...   ...   ...   ...   ...
# 491     VZ           Telecommunications Services  2.90  2.93  2.57  2.63
# 492    WBA                 Food & Drug Retailing  0.00  0.00  0.00  0.00
# 493    WFC                      Banking Services  0.86  0.93  0.97  2.74
# 494    WMT                 Food & Drug Retailing  2.04  2.07  2.04  2.18
# 495    XOM                             Oil & Gas  2.98  3.39  3.52  3.77
#
#      2019  2020  2021  2022  2023
# 0    1.50  1.50  3.00  3.00  3.00
# ...

# %% [markdown]
# ### Processing the ESG Data

# %%
esg_overall         = pd.melt(esg_overall, id_vars=['TICKER', 'Settore'], var_name='Year', value_name='esg overall')
esg_environmental   = pd.melt(esg_environmental, id_vars=['TICKER', 'Settore'], var_name='Year', value_name='esg environmental')
esg_social          = pd.melt(esg_social, id_vars=['TICKER', 'Settore'], var_name='Year', value_name='esg social')
esg_governance      = pd.melt(esg_governance, id_vars=['TICKER', 'Settore'], var_name='Year', value_name='esg governance')

# %% [markdown]
# ### Mergin into single esg dataframe

# %%
dfs = [esg_overall, esg_environmental, esg_social, esg_governance]
# Initialize the merged DataFrame with the first DataFrame
df_esg = dfs[0]
# Iterate over the remaining DataFrames and merge them
for df in dfs[1:]:
    df_esg = pd.merge(df_esg, df, on=['TICKER','Year','Settore'], how='left')
df_esg.sort_values(['TICKER','Year'])
# Out:
#      TICKER                          Settore  Year  esg overall  \
# 0         A  Healthcare Equipment & Supplies  2015         2.79
# 524       A  Healthcare Equipment & Supplies  2016         2.89
# 1048      A  Healthcare Equipment & Supplies  2017         2.97
# 1572      A  Healthcare Equipment & Supplies  2018         3.04
# 2096      A  Healthcare Equipment & Supplies  2019         3.19
# ...     ...                              ...   ...          ...
# 2505    ZTS                  Pharmaceuticals  2019         4.43
# 3029    ZTS                  Pharmaceuticals  2020         4.62
# 3553    ZTS                  Pharmaceuticals  2021         5.83
# 4077    ZTS                  Pharmaceuticals  2022         5.79
# 4601    ZTS                  Pharmaceuticals  2023         5.79
#
#       esg environmental  esg social  esg governance
# 0                  1.50        1.69            5.64
# 524                1.50        1.73            5.93
# ...

# %% [markdown]
# # Loading Downside Risk

# %%
df_downside_risk = pd.read_excel('data/risk/downside_risk.xlsx')
df_downside_risk = prep.process_downside_risk(df_downside_risk)
df_downside_risk.sort_values(['TICKER','Year'])
# Out:
#      TICKER  Year  downside risk
# 4060      A  2015            NaN
# 3565      A  2016       0.004315
# 3070      A  2017       0.002763
# 2575      A  2018       0.003050
# 2080      A  2019       0.005519
# ...     ...   ...            ...
# 2474    ZTS  2019       0.012924
# 1979    ZTS  2020       0.006780
# 1484    ZTS  2021       0.008454
# 989     ZTS  2022       0.009720
# 494     ZTS  2023       0.008314
#
# [4455 rows x 3 columns]

# %% [markdown]
# # Merging Data

# %%
df = pd.merge(df_financial,df_esg, on=['TICKER', 'Year'], how='left')
df = pd.merge(df,df_downside_risk, on=['TICKER', 'Year'], how='left')
df
# Out:
#      TICKER  Year  Current_Ratio  Debt_to_Equity  Net_Income_to_Assets  \
# 0         A  2012       2.445325        1.032015              0.109930
# 1         A  2013       3.110487        1.020420              0.069931
# 2         A  2014       3.231492        1.043199              0.043272
# 3         A  2015       3.776639        0.793525              0.052102
# 4         A  2016       3.846561        0.835610              0.058601
# ...     ...   ...            ...             ...                   ...
# 6396    XOM  2019       0.782197        0.822663              0.039674
# 6397    XOM  2020       0.796498        1.027356             -0.072319
# 6398    XOM  2021       1.044330        0.929174              0.065479
# 6399    XOM  2022       1.414020        0.822796              0.153927
# 6400    XOM  2023       1.479102        0.770587              0.097914
#
#       Operating_Margin  Cash_Ratio  Operating_Cash_Flow_Ratio  \
# ...

# %%
df.to_csv('data/processed_data/prepared_data.csv',index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.to_csv('data/processed_data/cleaned_data.csv',index = False)
#
# NameError: name 'df' is not defined
